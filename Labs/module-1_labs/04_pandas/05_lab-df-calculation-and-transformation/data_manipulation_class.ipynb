# %% [markdown]
# ## Manipulating Dataframes in Pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('vehicles.csv')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %% [markdown]
# #### Renaming columns

# %%
df = df.rename(columns={'Make':'Manufacturer'})

# %%
df.head()
# Out:
#        Manufacturer                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
df.rename(columns={'Make':'Manufacturer'}, inplace = True)

# %%
df.head()
# Out:
#        Manufacturer                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
df.rename(columns={'Make':'Manufacturer', 'Engine Displacement': 'Displacement'}, inplace = True)

# %%
df['Manufacturer'].head()
# Out:
# 0          AM General
# 1          AM General
# 2          AM General
# 3          AM General
# 4    ASC Incorporated
# Name: Manufacturer, dtype: object

# %% [markdown]
# #### Dropping columns

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Year', 'Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
df = df.drop('Fuel Cost/Year', axis = 1)

# %%
df = df.drop(['Highway MPG', 'City MPG'], axis = 1)

# %%
del df['Year']

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Displacement', 'Cylinders', 'Transmission',
#        'Drivetrain', 'Vehicle Class', 'Fuel Type', 'Fuel Barrels/Year',
#        'Combined MPG', 'CO2 Emission Grams/Mile'],
#       dtype='object')

# %% [markdown]
# #### Filtering Data

# %%
df_ford = df[df['Manufacturer']=='Ford']
df_ford.head()
# Out:
#       Manufacturer         Model  Displacement  Cylinders     Transmission  \
# 11440         Ford  Aerostar Van           2.3        4.0  Automatic 4-spd
# 11441         Ford  Aerostar Van           2.3        4.0     Manual 5-spd
# 11442         Ford  Aerostar Van           2.8        6.0  Automatic 4-spd
# 11443         Ford  Aerostar Van           2.8        6.0     Manual 5-spd
# 11444         Ford  Aerostar Van           3.0        6.0     Manual 5-spd
#
#              Drivetrain Vehicle Class Fuel Type  Fuel Barrels/Year  \
# 11440  Rear-Wheel Drive          Vans   Regular          17.347895
# 11441  Rear-Wheel Drive          Vans   Regular          13.733750
# 11442  Rear-Wheel Drive          Vans   Regular          19.388824
# 11443  Rear-Wheel Drive          Vans   Regular          18.311667
# 11444  Rear-Wheel Drive          Vans   Regular          17.347895
#
#        Combined MPG  CO2 Emission Grams/Mile
# 11440            19               467.736842
# 11441            24               370.291667
# 11442            17               522.764706
# 11443            18               493.722222
# 11444            19               467.736842

# %%
df_ford_1986 = df[(df['Manufacturer'] == 'Ford') & (df['Year'] == 1986)]

df_ford_1986.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-8d068b6b3f39> in <module>
# ----> 1 df_ford_1986 = df[(df['Manufacturer'] == 'Ford') & (df['Year'] == 1986)]
#       2
#       3 df_ford_1986.head()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'

# %%
df.describe()
# Out:
#        Displacement     Cylinders  Fuel Barrels/Year  Combined MPG  \
# count  35952.000000  35952.000000       35952.000000  35952.000000
# mean       3.338493      5.765076          17.609056     19.929322
# std        1.359395      1.755268           4.467283      5.112409
# min        0.600000      2.000000           0.060000      7.000000
# 25%        2.200000      4.000000          14.699423     16.000000
# 50%        3.000000      6.000000          17.347895     19.000000
# 75%        4.300000      6.000000          20.600625     23.000000
# max        8.400000     16.000000          47.087143     56.000000
#
#        CO2 Emission Grams/Mile
# count             35952.000000
# mean                475.316339
# std                 119.060773
# min                  37.000000
# 25%                 395.000000
# 50%                 467.736842
# 75%                 555.437500
# max                1269.571429

# %% [markdown]
# #### Calculations on Dataframes

# %%
df['hello'] = 'hello'
df.head()
# Out:
#        Manufacturer                Model  Displacement  Cylinders  \
# 0        AM General    DJ Po Vehicle 2WD           2.5        4.0
# 1        AM General     FJ8c Post Office           4.2        6.0
# 2        AM General  Post Office DJ5 2WD           2.5        4.0
# 3        AM General  Post Office DJ8 2WD           4.2        6.0
# 4  ASC Incorporated                  GNX           3.8        6.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 3  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 4  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars   Premium
#
#    Fuel Barrels/Year  Combined MPG  CO2 Emission Grams/Mile  hello
# 0          19.388824            17               522.764706  hello
# 1          25.354615            13               683.615385  hello
# 2          20.600625            16               555.437500  hello
# 3          25.354615            13               683.615385  hello
# 4          20.600625            16               555.437500  hello

# %%
df['Age'] = 2020 - df['Year']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-165ea736b002> in <module>
# ----> 1 df['Age'] = 2020 - df['Year']
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'

# %%
df['y2020'] = df['Age'] + df['Year']
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-faa74cf500fa> in <module>
# ----> 1 df['y2020'] = df['Age'] + df['Year']
#       2 df.head()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'

# %% [markdown]
# #### Applying Functions to Columns

# %%
df.describe()
# Out:
#        Displacement     Cylinders  Fuel Barrels/Year  Combined MPG  \
# count  35952.000000  35952.000000       35952.000000  35952.000000
# mean       3.338493      5.765076          17.609056     19.929322
# std        1.359395      1.755268           4.467283      5.112409
# min        0.600000      2.000000           0.060000      7.000000
# 25%        2.200000      4.000000          14.699423     16.000000
# 50%        3.000000      6.000000          17.347895     19.000000
# 75%        4.300000      6.000000          20.600625     23.000000
# max        8.400000     16.000000          47.087143     56.000000
#
#        CO2 Emission Grams/Mile
# count             35952.000000
# mean                475.316339
# std                 119.060773
# min                  37.000000
# 25%                 395.000000
# 50%                 467.736842
# 75%                 555.437500
# max                1269.571429

# %%
df.sum()
# Out:
# Manufacturer               AM GeneralAM GeneralAM GeneralAM GeneralASC In...
# Model                      DJ Po Vehicle 2WDFJ8c Post OfficePost Office D...
# Displacement                                                          120026
# Cylinders                                                             207266
# Transmission               Automatic 3-spdAutomatic 3-spdAutomatic 3-spdA...
# Drivetrain                 2-Wheel Drive2-Wheel DriveRear-Wheel DriveRear...
# Vehicle Class              Special Purpose Vehicle 2WDSpecial Purpose Veh...
# Fuel Type                  RegularRegularRegularRegularPremiumRegularRegu...
# Fuel Barrels/Year                                                     633081
# Combined MPG                                                          716499
# CO2 Emission Grams/Mile                                          1.70886e+07
# hello                      hellohellohellohellohellohellohellohellohelloh...
# dtype: object

# %%
df.sum(axis = 1)
# Out:
# 0        565.653529
# 1        732.170000
# 2        598.538125
# 3        732.170000
# 4        601.838125
#             ...
# 35947    293.155833
# 35948    292.155833
# 35949    293.155833
# 35950    295.055833
# 35951    303.317429
# Length: 35952, dtype: float64

# %%
df[['Year', 'City MPG']].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-764473f7b589> in <module>
# ----> 1 df[['Year', 'City MPG']].sum()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Year', 'City MPG'], dtype='object')] are in the [columns]"

# %%
columns_to_compute = ['Year', 'City MPG']
df[columns_to_compute].sum()

# %%
df[['Year', 'City MPG']].max()

# %%
df = df.sort_values(by = 'Year')

df.sort_values(by = 'Year', inplace = True, ascending = False)

# %%
df.sort_values?

# %%
df.sort_values(by = ['Year', 'City MPG'])

# %%
df.nlargest(3, 'Year')

# %%
largest_three = df.nlargest(3, ['Year', 'City MPG'])

# %% [markdown]
# #### Using df.apply

# %%
df['Manufacturer'].str.upper()

# %%
df['Manufacturer'].apply(lambda x: x.replace('e', 'b'))

# %%
#df['Manufacturer'].apply(str.upper)
df['Manufacturer'].apply(lambda x: x.upper())
# Out:
# 0              AM GENERAL
# 1              AM GENERAL
# 2              AM GENERAL
# 3              AM GENERAL
# 4        ASC INCORPORATED
#                ...
# 35947               SMART
# 35948               SMART
# 35949               SMART
# 35950               SMART
# 35951               SMART
# Name: Manufacturer, Length: 35952, dtype: object

# %%
subset = df[['Manufacturer', 'Vehicle Class']]
for i in range(len(subset.columns)):
    print(df[subset.columns[i]].apply(lambda x: x.replace('e', 'b')))
# Out:
# 0              AM Gbnbral
# 1              AM Gbnbral
# 2              AM Gbnbral
# 3              AM Gbnbral
# 4        ASC Incorporatbd
#                ...
# 35947               smart
# 35948               smart
# 35949               smart
# 35950               smart
# 35951               smart
# Name: Manufacturer, Length: 35952, dtype: object
# 0        Spbcial Purposb Vbhiclb 2WD
# 1        Spbcial Purposb Vbhiclb 2WD
# 2        Spbcial Purposb Vbhiclb 2WD
# 3        Spbcial Purposb Vbhiclb 2WD
# 4                       Midsizb Cars
#                     ...
# 35947                    Two Sbatbrs
# 35948                    Two Sbatbrs
# 35949                    Two Sbatbrs
# 35950                    Two Sbatbrs
# 35951                    Two Sbatbrs
# Name: Vehicle Class, Length: 35952, dtype: object

# %% [markdown]
# #### Dataframe Aggregation using groupby

# %%
df.mean()
# Out:
# Displacement                 3.338493
# Cylinders                    5.765076
# Fuel Barrels/Year           17.609056
# Combined MPG                19.929322
# CO2 Emission Grams/Mile    475.316339
# dtype: float64

# %%
df.groupby(['Fuel Type', 'Manufacturer']).mean()
# Out:
#                                           Displacement  Cylinders  \
# Fuel Type                   Manufacturer
# CNG                         Chevrolet         6.000000       8.00
#                             Dodge             4.487500       7.25
#                             Ford              5.063158       8.00
#                             GMC               6.000000       8.00
#                             Honda             1.738889       4.00
# ...                                                ...        ...
# Regular Gas and Electricity Ford              2.000000       4.00
#                             Honda             2.000000       4.00
#                             Hyundai           2.000000       4.00
#                             Toyota            1.800000       4.00
# Regular Gas or Electricity  Chevrolet         1.500000       4.00
#
#                                           Fuel Barrels/Year  Combined MPG  \
# Fuel Type                   Manufacturer
# CNG                         Chevrolet              0.181867     10.400000
#                             Dodge                  0.133433     14.250000
#                             Ford                   0.138454     13.736842
#                             GMC                    0.180833     10.500000
#                             Honda                  0.065410     28.500000
# ...                                                     ...           ...
# Regular Gas and Electricity Ford                   4.801412     38.444444
#                             Honda                  4.827657     46.000000
#                             Hyundai                3.858080     39.500000
#                             Toyota                 4.739011     50.000000
# Regular Gas or Electricity  Chevrolet              2.006844     42.000000
#
#                                           CO2 Emission Grams/Mile
# Fuel Type                   Manufacturer
# CNG                         Chevrolet                  693.198000
#                             Dodge                      508.590547
#                             Ford                       527.726359
#                             GMC                        689.259375
#                             Honda                      247.532772
# ...                                                           ...
# Regular Gas and Electricity Ford                       127.111111
#                             Honda                      130.000000
#                             Hyundai                    102.500000
#                             Toyota                     133.000000
# Regular Gas or Electricity  Chevrolet                   51.000000
#
# [265 rows x 5 columns]

# %%
df.groupby(['Fuel Type'])['Cylinders', 'City MPG'].mean()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-6db218e0a8c2> in <module>
# ----> 1 df.groupby(['Fuel Type'])['Cylinders', 'City MPG'].mean()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1601                 stacklevel=2,
#    1602             )
# -> 1603         return super().__getitem__(key)
#    1604
#    1605     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/base.py in __getitem__(self, key)
#     218             if len(self.obj.columns.intersection(key)) != len(key):
#     219                 bad_keys = list(set(key).difference(self.obj.columns))
# --> 220                 raise KeyError(f"Columns not found: {str(bad_keys)[1:-1]}")
#     221             return self._gotitem(list(key), ndim=2)
#     222
#
# KeyError: "Columns not found: 'City MPG'"

# %%
df.groupby(['Fuel Type'])['Cylinders', 'City MPG'].agg(['mean', 'max', 'min'])
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                             Cylinders              City MPG
#                                  mean   max  min       mean max min
# Fuel Type
# CNG                          6.500000   8.0  4.0  15.966667  27   8
# Diesel                       6.225027  10.0  4.0  21.173436  38  13
# Gasoline or E85              6.974059   8.0  4.0  15.347280  28  10
# Gasoline or natural gas      6.800000   8.0  4.0  13.700000  21  10
# Gasoline or propane          8.000000   8.0  8.0  12.000000  13  11
# Midgrade                     7.864865   8.0  6.0  14.851351  21  13
# Premium                      6.365286  16.0  2.0  16.793166  42   6
# Premium Gas or Electricity   4.235294   8.0  2.0  30.705882  41  20
# Premium and Electricity      4.850000   8.0  3.0  24.900000  37  16
# Premium or E85               6.892562  12.0  4.0  17.305785  24  11
# Regular                      5.420952  12.0  2.0  17.970195  58   7
# Regular Gas and Electricity  4.000000   4.0  4.0  43.125000  51  38
# Regular Gas or Electricity   4.000000   4.0  4.0  43.000000  43  43

# %%
grouped1 = df.groupby(['Fuel Type'])['Cylinders', 'City MPG'].mean()
grouped2 = df.groupby(['Fuel Type'])['Cylinders', 'City MPG'].mean().reset_index()

# %%
print(grouped1)
print(grouped2)

# %%
grouped1['Cylinders']

# %%
avg_mpg = df.groupby('Make', as_index=False).agg({'Combined MPG':'mean'})

# %%
avg_mpg
# Out:
#                             Make  Combined MPG
# 0                     AM General     14.750000
# 1               ASC Incorporated     16.000000
# 2                          Acura     21.506623
# 3                     Alfa Romeo     19.512195
# 4    American Motors Corporation     17.681818
# ..                           ...           ...
# 122                   Volkswagen     24.093601
# 123                        Volvo     20.605300
# 124        Wallace Environmental     13.875000
# 125                         Yugo     25.000000
# 126                        smart     35.800000
#
# [127 rows x 2 columns]

# %%
avg_mpg1 = df.groupby(['Make'], as_index=False).agg({'Combined MPG':'mean', 'Cylinders':'sum'})

# %%
avg_mpg1
# Out:
#                             Make  Combined MPG  Cylinders
# 0                     AM General     14.750000       20.0
# 1               ASC Incorporated     16.000000        6.0
# 2                          Acura     21.506623     1580.0
# 3                     Alfa Romeo     19.512195      218.0
# 4    American Motors Corporation     17.681818      122.0
# ..                           ...           ...        ...
# 122                   Volkswagen     24.093601     4811.0
# 123                        Volvo     20.605300     3546.0
# 124        Wallace Environmental     13.875000      250.0
# 125                         Yugo     25.000000       32.0
# 126                        smart     35.800000       60.0
#
# [127 rows x 3 columns]

# %%
avg_mpg3 = df.groupby(['Make'])['Combined MPG'].agg(['mean'])

# %%
avg_mpg3
# Out:
#                                   mean
# Make
# AM General                   14.750000
# ASC Incorporated             16.000000
# Acura                        21.506623
# Alfa Romeo                   19.512195
# American Motors Corporation  17.681818
# ...                                ...
# Volkswagen                   24.093601
# Volvo                        20.605300
# Wallace Environmental        13.875000
# Yugo                         25.000000
# smart                        35.800000
#
# [127 rows x 1 columns]

# %%
avg_mpg4 = df.groupby(['Make'], as_index=False)['Combined MPG'].agg(['mean']).reset_index()

# %%
avg_mpg4
# Out:
#                             Make       mean
# 0                     AM General  14.750000
# 1               ASC Incorporated  16.000000
# 2                          Acura  21.506623
# 3                     Alfa Romeo  19.512195
# 4    American Motors Corporation  17.681818
# ..                           ...        ...
# 122                   Volkswagen  24.093601
# 123                        Volvo  20.605300
# 124        Wallace Environmental  13.875000
# 125                         Yugo  25.000000
# 126                        smart  35.800000
#
# [127 rows x 2 columns]
